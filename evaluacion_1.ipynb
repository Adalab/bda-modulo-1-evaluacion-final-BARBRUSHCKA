# %% [markdown]
# INVENTARIO

# %%
diccionary=[]

# %%
type(diccionary)
# Out:
# list

# %%
inventory={}

# %%
products= [{"lencero":"vestido", "precio":79.95,"cantidad":40 },
           {"abrigo_corto":"abrigo", "precio": 59.95, "cantidad": 20}, 
           {"blazer_abierto_cuello":"blazer", "precio": 39.95, "cantidad":80},
           {"plumifero_relleno":"abrigo","precio": 99.95, "cantidad":15},
           {"anorak":"abrigos","precio": 49.95,"cantidad": 5},
           {"body_asimetrico":"body", "precio":17.95,"cantidad":30},
           {"jeans_tiro_alto":"pantalones", "precio":25.95,"cantidad": 25},
           {"bolso_choper":"bolso", "precio": 35.95, "cantidad":9.95},
           {"lip_oil": "labial","precio":9.95,"cantidad":85},
           {"red_tentation":"perfume","precio":15.95, "cantidad":90},
           {"bota_alta":"bota", "precio": 220, "cantidad":5}]
