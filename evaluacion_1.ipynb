# %% [markdown]
# INVENTARIO

# %%
diccionario=[]

# %%
type(diccionario)
# Out:
# list

# %%
inventario={}

# %%
productos= [{"lencero":"vestido", "precio":79.95,"cantidad":40 },{"abrigo_corto":"abrigo", "precio": 59.95, "cantidad": 20}, {"blazer_abierto_cuello":"blazer", "precio": 39.95, "cantidad":80}
            {}
